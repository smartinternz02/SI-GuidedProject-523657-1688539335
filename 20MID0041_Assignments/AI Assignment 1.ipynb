# %%
import numpy as np
import pandas as pd
#generating random values
d = np.random.rand(4, 4)
# Creating a DataFrame
df = pd.DataFrame(d, columns=['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4'], index =['Observation 1','Observation 2','Observation 3','Observation 4'])
# Print the DataFrame
print(df)
# Out:
#                Feature 1  Feature 2  Feature 3  Feature 4
# Observation 1   0.843391   0.179645   0.985397   0.523939
# Observation 2   0.175740   0.319882   0.185865   0.301711
# Observation 3   0.280659   0.605286   0.987745   0.484425
# Observation 4   0.921194   0.586177   0.484705   0.231538

# %%
import numpy as np
import pandas as pd
#Renaming Columns
df = df.rename(columns = {'Feature 1' : 'Random Value 1',
 'Feature 2' : 'Random Value 2',
'Feature 3' : 'Random Value 3',
'Feature 4' : 'Random Value 4'})
# Print the DataFrame
print(df)
# Out:
#                Random Value 1  Random Value 2  Random Value 3  Random Value 4
# Observation 1        0.843391        0.179645        0.985397        0.523939
# Observation 2        0.175740        0.319882        0.185865        0.301711
# Observation 3        0.280659        0.605286        0.987745        0.484425
# Observation 4        0.921194        0.586177        0.484705        0.231538

# %%
import numpy as np
import pandas as pd
#Statistical Description
stat = df.describe()
# Print the DataFrame
print(df)
print('\n')
print(stat)
# Out:
#                Random Value 1  Random Value 2  Random Value 3  Random Value 4
# Observation 1        0.843391        0.179645        0.985397        0.523939
# Observation 2        0.175740        0.319882        0.185865        0.301711
# Observation 3        0.280659        0.605286        0.987745        0.484425
# Observation 4        0.921194        0.586177        0.484705        0.231538
#
#
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.555246        0.422747        0.660928        0.385403
# std          0.381387        0.207934        0.395318        0.141040
# min          0.175740        0.179645        0.185865        0.231538
# 25%          0.254429        0.284823        0.409995        0.284168
# 50%          0.562025        0.453029        0.735051        0.393068
# 75%          0.862842        0.590954        0.985984        0.494304
# max          0.921194        0.605286        0.987745        0.523939

# %%
import numpy as np
import pandas as pd
#Checking NULL values
null_val = df.isnull().sum()
#Checking Data types
data_type = df.dtypes
# Print the DataFrame
print(null_val)
print('\n')
print(data_type)
# Out:
# Random Value 1    0
# Random Value 2    0
# Random Value 3    0
# Random Value 4    0
# dtype: int64
#
#
# Random Value 1    float64
# Random Value 2    float64
# Random Value 3    float64
# Random Value 4    float64
# dtype: object

# %%
import numpy as np
import pandas as pd
# Display columns using the location method
location_method = df[['Random Value 2', 'Random Value 3']]
print("Columns using location method:")
print(location_method)
# Display columns using the index location method
index_location_method = df.iloc[:, 1:3]
print("\nColumns using index location method :")
print(index_location_method)
# Out:
# Columns using location method:
#                Random Value 2  Random Value 3
# Observation 1        0.179645        0.985397
# Observation 2        0.319882        0.185865
# Observation 3        0.605286        0.987745
# Observation 4        0.586177        0.484705
#
# Columns using index location method :
#                Random Value 2  Random Value 3
# Observation 1        0.179645        0.985397
# Observation 2        0.319882        0.185865
# Observation 3        0.605286        0.987745
# Observation 4        0.586177        0.484705
